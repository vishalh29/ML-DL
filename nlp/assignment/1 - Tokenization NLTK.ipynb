# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 3.7 MB/s eta 0:00:01
# Collecting joblib
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      |████████████████████████████████| 309 kB 18.1 MB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 23.7 MB/s eta 0:00:01
# Collecting click
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 30.3 MB/s eta 0:00:01
# Collecting regex>=2021.8.3
#   Downloading regex-2026.1.15-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
#      |████████████████████████████████| 288 kB 45.6 MB/s eta 0:00:01
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.8 joblib-1.5.3 nltk-3.9.2 regex-2026.1.15 tqdm-4.67.3
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.tokenize import sent_tokenize

sentence="The Eiffel Tower was built. from 1887 to 1889 by! French ! engineer Gustave Eiffel. whose company specialized in building metal frameworks and structures."

tokenized_sentences=sent_tokenize(sentence)

tokenized_sentences
# Out:
# ['The Eiffel Tower was built.',
#  'from 1887 to 1889 by!',
#  'French !',
#  'engineer Gustave Eiffel.',
#  'whose company specialized in building metal frameworks and structures.']

# %%
for i in tokenized_sentences:
    print(i)
# Out:
# The Eiffel Tower was built.
# from 1887 to 1889 by!
# French !
# engineer Gustave Eiffel.
# whose company specialized in building metal frameworks and structures.

# %%
from nltk.tokenize import word_tokenize

word_tokenize(sentence)
# Out:
# ['The',
#  'Eiffel',
#  'Tower',
#  'was',
#  'built',
#  '.',
#  'from',
#  '1887',
#  'to',
#  '1889',
#  'by',
#  '!',
#  'French',
#  '!',
#  'engineer',
#  'Gustave',
#  'Eiffel',
#  '.',
#  'whose',
#  'company',
#  'specialized',
#  'in',
#  'building',
#  'metal',
#  'frameworks',
#  'and',
#  'structures',
#  '.']

# %%
for i in tokenized_sentences:
    print(word_tokenize(i))
# Out:
# ['The', 'Eiffel', 'Tower', 'was', 'built', '.']
# ['from', '1887', 'to', '1889', 'by', '!']
# ['French', '!']
# ['engineer', 'Gustave', 'Eiffel', '.']
# ['whose', 'company', 'specialized', 'in', 'building', 'metal', 'frameworks', 'and', 'structures', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# wordpunct_tokenize(sentence)

for i in tokenized_sentences:
    print(wordpunct_tokenize(i))
# Out:
# ['The', 'Eiffel', 'Tower', 'was', 'built', '.']
# ['from', '1887', 'to', '1889', 'by', '!']
# ['French', '!']
# ['engineer', 'Gustave', 'Eiffel', '.']
# ['whose', 'company', 'specialized', 'in', 'building', 'metal', 'frameworks', 'and', 'structures', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer=TreebankWordTokenizer()

tokenizer.tokenize(sentence)
# Out:
# ['The',
#  'Eiffel',
#  'Tower',
#  'was',
#  'built.',
#  'from',
#  '1887',
#  'to',
#  '1889',
#  'by',
#  '!',
#  'French',
#  '!',
#  'engineer',
#  'Gustave',
#  'Eiffel.',
#  'whose',
#  'company',
#  'specialized',
#  'in',
#  'building',
#  'metal',
#  'frameworks',
#  'and',
#  'structures',
#  '.']
